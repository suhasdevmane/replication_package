# %%
# Define the raw data for each category
data = {
    "INTRO": [8, 27, 9, 35],
    "METHD1": [74, 59, 192],
    "STANDARDS": [32,185,36,37,39,14,82,15,81,19,71,83,21,39,36,37,112,3,97,36],
    "ENERGY": [22,18,28,94,123,143,20,30,44,51,90,183,191,202,80,148,63,88,85,178,63,88,110,152,166,179,68,161,195,107,86,1,164,1,4,10,12,13,17,20,24,29,30,40,41,43,47,51,61,65,73,75,80,90,100,101,104,106,110,115,123,132,134,139,140,148,160,166,171,176,179,181,183,190,191,195,4,10,17,10,17,41,77,104,127,130,114,44,143,203,72,136,66,31,119,151,198,38,96,28,193,182,84,12,173,158,73,179,139,146,180],
    "THERMAL": [174,114,44,143,203,136,66,119,31,38,96,28,84,12,173,158,204,58,60,147,99,162,163,172,138,108,78,199,34,64,70,89,135,67,121,79,120,187,125,188,147,162,163,172,99,109,138,157,196,131,103,91,54,126,145,44,124,134,128,79,114,93,67,58,60,1,141,149,1,2,4,10,24,29,41,49,51,51,52,61,65,69,73,75,80,90,93,104,115,123,132,134,140,148,159,179,195,200,4,10,23,10,41,77,104,127,156,159,160,105,156,134,124,145,126,54,157,196,79,114,143,93,73,179],
    "IAQ": [144,6,16,48,46,129,44,122,46,195,5,195,57,24,72,207,46,195,129,62,206,44,169,45,129,61,195,183,102,1,141,1,4,10,13,44,51,61,65,73,90,93,102,115,129,142,152,183,195,202,4,10,23,10,77,127,156,130,156,197,128,44,72,136,38],
    "SENSING": [113,201,189,53,76,98,95,109,116,177,11,50,118,175,139,56,143,203,150,72,38,136,66,133,28,111,117,119,198,179,134,128,143,203,72,136,31,119,151,198,38,92,139,146,180,28,193,173,158,73,179],
    "HBE": [165,155,17,10,55,26,29,41,104,87,127,184,24,168,153,1,141,98,170,186,137,179,167,33,205,7,42]
}

# Process the data to remove duplicates and count unique values
results = {}
print("=== Unique Tuples and Counts ===\n")
for category, numbers in data.items():
    unique_numbers = tuple(sorted(set(numbers)))  # remove duplicates and sort
    results[category] = unique_numbers
    print(f"{category}:")
    print(f"  Unique tuple: {unique_numbers}")
    print(f"  Count: {len(unique_numbers)}\n")

# Print summary table
print("=== Summary Table ===")
print("{:<12}{}".format("Category", "Unique Count"))
print("-" * 50)
for category, unique_numbers in results.items():
    print("{:<12}{}".format(category, len(unique_numbers)))
# Out:
# === Unique Tuples and Counts ===
#
# INTRO:
#   Unique tuple: (8, 9, 27, 35)
#   Count: 4
#
# METHD1:
#   Unique tuple: (59, 74, 192)
#   Count: 3
#
# STANDARDS:
#   Unique tuple: (3, 14, 15, 19, 21, 32, 36, 37, 39, 71, 81, 82, 83, 97, 112, 185)
#   Count: 16
#
# ENERGY:
#   Unique tuple: (1, 4, 10, 12, 13, 17, 18, 20, 22, 24, 28, 29, 30, 31, 38, 40, 41, 43, 44, 47, 51, 61, 63, 65, 66, 68, 72, 73, 75, 77, 80, 84, 85, 86, 88, 90, 94, 96, 100, 101, 104, 106, 107, 110, 114, 115, 119, 123, 127, 130, 132, 134, 136, 139, 140, 143, 146, 148, 151, 152, 158, 160, 161, 164, 166, 171, 173, 176, 178, 179, 180, 181, 182, 183, 190, 191, 193, 195, 198, 202, 203)
#   Count: 81
#
# THERMAL:
# ...

# %%
# Install matplotlib-venn if you don't have it
# !pip install matplotlib-venn

from matplotlib import pyplot as plt
from matplotlib_venn import venn3

# Your category data
ENERGY = [22,18,28,94,123,143,20,30,44,51,90,183,191,202,80,148,63,88,85,178,63,88,110,152,166,179,68,161,195,107,86,1,164,1,4,10,12,13,17,20,24,29,30,40,41,43,47,51,61,65,73,75,80,90,100,101,104,106,110,115,123,132,134,139,140,148,160,166,171,176,179,181,183,190,191,195,4,10,17,10,17,41,77,104,127,130,114,44,143,203,72,136,66,31,119,151,198,38,96,28,193,182,84,12,173,158,73,179,139,146,180]
THERMAL = [174,114,44,143,203,136,66,119,31,38,96,28,84,12,173,158,204,58,60,147,99,162,163,172,138,108,78,199,34,64,70,89,135,67,121,79,120,187,125,188,147,162,163,172,99,109,138,157,196,131,103,91,54,126,145,44,124,134,128,79,114,93,67,58,60,1,141,149,1,2,4,10,24,29,41,49,51,51,52,61,65,69,73,75,80,90,93,104,115,123,132,134,140,148,159,179,195,200,4,10,23,10,41,77,104,127,156,159,160,105,156,134,124,145,126,54,157,196,79,114,143,93,73,179]
IAQ = [144,6,16,48,46,129,44,122,46,195,5,195,57,24,72,207,46,195,129,62,206,44,169,45,129,61,195,183,102,1,141,1,4,10,13,44,51,61,65,73,90,93,102,115,129,142,152,183,195,202,4,10,23,10,77,127,130,156,130,156,197,128,44,72,136,38]

# Convert to sets to remove duplicates and enable set operations
energy_set = set(ENERGY)
thermal_set = set(THERMAL)
iaq_set = set(IAQ)

# Create the Venn diagram
plt.figure(figsize=(7, 6))
venn3([energy_set, thermal_set, iaq_set],
      set_labels=('ENERGY', 'THERMAL', 'IAQ'))

plt.title("Overlap of Citations Across ENERGY, THERMAL, and IAQ")
plt.show()

# Optional: also print raw counts
only_energy = len(energy_set - thermal_set - iaq_set)
only_thermal = len(thermal_set - energy_set - iaq_set)
only_iaq = len(iaq_set - energy_set - thermal_set)
energy_thermal = len((energy_set & thermal_set) - iaq_set)
energy_iaq = len((energy_set & iaq_set) - thermal_set)
thermal_iaq = len((thermal_set & iaq_set) - energy_set)
all_three = len(energy_set & thermal_set & iaq_set)

print("\n=== Counts ===")
print("Only ENERGY:", only_energy)
print("Only THERMAL:", only_thermal)
print("Only IAQ:", only_iaq)
print("ENERGY & THERMAL:", energy_thermal)
print("ENERGY & IAQ:", energy_iaq)
print("THERMAL & IAQ:", thermal_iaq)
print("All three:", all_three)
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.1 MB 12.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.1 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 11.7 MB/s  0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1 — your raw data
categories = {
    "INTRO": [8,27,9,35],
    "METHD1": [74,59,192],
    "STANDARDS": [32,185,36,37,39,14,82,15,81,19,71,83,21,39,36,37,112,3,97,36],
    "ENERGY": [22,18,28,94,123,143,20,30,44,51,90,183,191,202,80,148,63,88,85,178,63,88,110,152,166,179,68,161,195,107,86,1,164,1,4,10,12,13,17,20,24,29,30,40,41,43,47,51,61,65,73,75,80,90,100,101,104,106,110,115,123,132,134,139,140,148,160,166,171,176,179,181,183,190,191,195,4,10,17,10,17,41,77,104,127,130,114,44,143,203,72,136,66,31,119,151,198,38,96,28,193,182,84,12,173,158,73,179,139,146,180],
    "THERMAL": [174,114,44,143,203,136,66,119,31,38,96,28,84,12,173,158,204,58,60,147,99,162,163,172,138,108,78,199,34,64,70,89,135,67,121,79,120,187,125,188,147,162,163,172,99,109,138,157,196,131,103,91,54,126,145,44,124,134,128,79,114,93,67,58,60,1,141,149,1,2,4,10,24,29,41,49,51,51,52,61,65,69,73,75,80,90,93,104,115,123,132,134,140,148,159,179,195,200,4,10,23,10,41,77,104,127,156,159,160,105,156,134,124,145,126,54,157,196,79,114,143,93,73,179],
    "IAQ": [144,6,16,48,46,129,44,122,46,195,5,195,57,24,72,207,46,195,129,62,206,44,169,45,129,61,195,183,102,1,141,1,4,10,13,44,51,61,65,73,90,93,102,115,129,142,152,183,195,202,4,10,23,10,77,127,130,156,130,156,197,128,44,72,136,38],
    "SENSING": [113,201,189,53,76,98,95,109,116,177,11,50,118,175,139,56,143,203,150,72,38,136,66,133,28,111,117,119,198,179,134,128,143,203,72,136,31,119,151,198,38,92,139,146,180,28,193,173,158,73,179],
    "HBE": [165,155,17,10,55,26,29,41,104,87,127,184,24,168,153,1,141,98,170,186,137,179,167,33,205,7,42]
}

# Step 2 — get all unique citation IDs
all_citations = sorted(set(num for nums in categories.values() for num in nums))

# Create a DataFrame with all citations as rows and all categories as columns
df = pd.DataFrame(0, index=all_citations, columns=categories.keys())

# Step 3 — mark 1 if a citation belongs to that category
for cat, nums in categories.items():
    df.loc[list(nums), cat] = 1

# Step 4 — count how many categories each citation belongs to
df['category_count'] = df.sum(axis=1)

# Step 5 — visualize how many citations fall into 1, 2, 3... categories
count_distribution = df['category_count'].value_counts().sort_index()

plt.figure(figsize=(8, 5))
count_distribution.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Number of Categories Each Citation Belongs To')
plt.xlabel('Number of Categories')
plt.ylabel('Number of Citations')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# Step 6 — calculate pairwise overlap between categories
overlap = df.drop(columns='category_count').T.dot(df.drop(columns='category_count'))

plt.figure(figsize=(8, 6))
sns.heatmap(overlap.astype(int), annot=True, fmt='d', cmap='Blues')
plt.title('Pairwise Overlap Between Categories')
plt.tight_layout()
plt.show()

# Optional: save to CSV for further analysis
df.to_csv("citation_category_matrix.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1 — your filtered data (only main technical categories)
categories = {
    "ENERGY": [22,18,28,94,123,143,20,30,44,51,90,183,191,202,80,148,63,88,85,178,63,88,110,152,166,179,68,161,195,107,86,1,164,1,4,10,12,13,17,20,24,29,30,40,41,43,47,51,61,65,73,75,80,90,100,101,104,106,110,115,123,132,134,139,140,148,160,166,171,176,179,181,183,190,191,195,4,10,17,10,17,41,77,104,127,130,114,44,143,203,72,136,66,31,119,151,198,38,96,28,193,182,84,12,173,158,73,179,139,146,180],
    "THERMAL": [174,114,44,143,203,136,66,119,31,38,96,28,84,12,173,158,204,58,60,147,99,162,163,172,138,108,78,199,34,64,70,89,135,67,121,79,120,187,125,188,147,162,163,172,99,109,138,157,196,131,103,91,54,126,145,44,124,134,128,79,114,93,67,58,60,1,141,149,1,2,4,10,24,29,41,49,51,51,52,61,65,69,73,75,80,90,93,104,115,123,132,134,140,148,159,179,195,200,4,10,23,10,41,77,104,127,156,159,160,105,156,134,124,145,126,54,157,196,79,114,143,93,73,179],
    "IAQ": [144,6,16,48,46,129,44,122,46,195,5,195,57,24,72,207,46,195,129,62,206,44,169,45,129,61,195,183,102,1,141,1,4,10,13,44,51,61,65,73,90,93,102,115,129,142,152,183,195,202,4,10,23,10,77,127,130,156,130,156,197,128,44,72,136,38],
    "SENSING": [113,201,189,53,76,98,95,109,116,177,11,50,118,175,139,56,143,203,150,72,38,136,66,133,28,111,117,119,198,179,134,128,143,203,72,136,31,119,151,198,38,92,139,146,180,28,193,173,158,73,179],
    "HBE": [165,155,17,10,55,26,29,41,104,87,127,184,24,168,153,1,141,98,170,186,137,179,167,33,205,7,42]
}

# Step 2 — get all unique citation IDs
all_citations = sorted(set(num for nums in categories.values() for num in nums))

# Step 3 — create a DataFrame with citations as rows and categories as columns
df = pd.DataFrame(0, index=all_citations, columns=categories.keys())

# Step 4 — mark 1 if a citation belongs to that category
for cat, nums in categories.items():
    df.loc[list(nums), cat] = 1

# Step 5 — count how many categories each citation belongs to
df['category_count'] = df.sum(axis=1)

# Step 6 — visualize distribution of how many categories each citation belongs to
count_distribution = df['category_count'].value_counts().sort_index()

plt.figure(figsize=(8, 5))
count_distribution.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Number of Categories Each Citation Belongs To')
plt.xlabel('Number of Categories')
plt.ylabel('Number of Citations')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# Step 7 — pairwise overlap matrix
overlap = df.drop(columns='category_count').T.dot(df.drop(columns='category_count'))

plt.figure(figsize=(7, 6))
sns.heatmap(overlap.astype(int), annot=True, fmt='d', cmap='Blues')
plt.title('Pairwise Overlap Between Categories')
plt.tight_layout()
plt.show()

# Step 8 — save to CSV for further analysis (optional)
df.to_csv("citation_category_matrix_filtered.csv")

# %%
# Original sets from your data
energy = {22,18,28,94,123,143,20,30,44,51,90,183,191,202,80,148,63,88,85,178,63,88,110,152,166,179,68,161,195,107,86,1,164,1,4,10,12,13,17,20,24,29,30,40,41,43,47,51,61,65,73,75,80,90,100,101,104,106,110,115,123,132,134,139,140,148,160,166,171,176,179,181,183,190,191,195,4,10,17,10,17,41,77,104,127,130,114,44,143,203,72,136,66,31,119,151,198,38,96,28,193,182,84,12,173,158,73,179,139,146,180}

thermal = {174,114,44,143,203,136,66,119,31,38,96,28,84,12,173,158,204,58,60,147,99,162,163,172,138,108,78,199,34,64,70,89,135,67,121,79,120,187,125,188,147,162,163,172,99,109,138,157,196,131,103,91,54,126,145,44,124,134,128,79,114,93,67,58,60,1,141,149,1,2,4,10,24,29,41,49,51,51,52,61,65,69,73,75,80,90,93,104,115,123,132,134,140,148,159,179,195,200,4,10,23,10,41,77,104,127,156,159,160,105,156,134,124,145,126,54,157,196,79,114,143,93,73,179}

iaq = {144,6,16,48,46,129,44,122,46,195,5,195,57,24,72,207,46,195,129,62,206,44,169,45,129,61,195,183,102,1,141,1,4,10,13,44,51,61,65,73,90,93,102,115,129,142,152,183,195,202,4,10,23,10,77,127,156,130,156,197,128,44,72,136,38}

# Find numbers that appear in more than one category
overlap = (energy & thermal) | (energy & iaq) | (thermal & iaq)

# Remove overlapping numbers from each category
energy_unique = sorted(energy - overlap)
thermal_unique = sorted(thermal - overlap)
iaq_unique = sorted(iaq - overlap)

# Print results
print("Unique ENERGY:", energy_unique, "\nCount:", len(energy_unique))
print("Unique THERMAL:", thermal_unique, "\nCount:", len(thermal_unique))
print("Unique IAQ:", iaq_unique, "\nCount:", len(iaq_unique))
# Out:
# Unique ENERGY: [17, 18, 20, 22, 30, 40, 43, 47, 63, 68, 85, 86, 88, 94, 100, 101, 106, 107, 110, 139, 146, 151, 161, 164, 166, 171, 176, 178, 180, 181, 182, 190, 191, 193, 198]
# Count: 35
# Unique THERMAL: [2, 34, 49, 52, 54, 58, 60, 64, 67, 69, 70, 78, 79, 89, 91, 99, 103, 105, 108, 109, 120, 121, 124, 125, 126, 131, 135, 138, 145, 147, 149, 157, 159, 162, 163, 172, 174, 187, 188, 196, 199, 200, 204]
# Count: 43
# Unique IAQ: [5, 6, 16, 45, 46, 48, 57, 62, 102, 122, 129, 142, 144, 169, 197, 206, 207]
# Count: 17

# %%
data = {
    "INTRO": [8, 27, 9, 35],
    "METHD1": [74, 59, 192],
    "STANDARDS": [32,185,36,37,39,14,82,15,81,19,71,83,21,39,36,37,112,3,97,36],
    "ENERGY": [22,18,28,94,123,143,20,30,44,51,90,183,191,202,80,148,63,88,85,178,63,88,110,152,166,179,68,161,195,107,86,1,164,1,4,10,12,13,17,20,24,29,30,40,41,43,47,51,61,65,73,75,80,90,100,101,104,106,110,115,123,132,134,139,140,148,160,166,171,176,179,181,183,190,191,195,4,10,17,10,17,41,77,104,127,130,114,44,143,203,72,136,66,31,119,151,198,38,96,28,193,182,84,12,173,158,73,179,139,146,180],
    "THERMAL": [174,114,44,143,203,136,66,119,31,38,96,28,84,12,173,158,204,58,60,147,99,162,163,172,138,108,78,199,34,64,70,89,135,67,121,79,120,187,125,188,147,162,163,172,99,109,138,157,196,131,103,91,54,126,145,44,124,134,128,79,114,93,67,58,60,1,141,149,1,2,4,10,24,29,41,49,51,51,52,61,65,69,73,75,80,90,93,104,115,123,132,134,140,148,159,179,195,200,4,10,23,10,41,77,104,127,156,159,160,105,156,134,124,145,126,54,157,196,79,114,143,93,73,179],
    "IAQ": [144,6,16,48,46,129,44,122,46,195,5,195,57,24,72,207,46,195,129,62,206,44,169,45,129,61,195,183,102,1,141,1,4,10,13,44,51,61,65,73,90,93,102,115,129,142,152,183,195,202,4,10,23,10,77,127,156,130,156,197,128,44,72,136,38],
    "SENSING": [113,201,189,53,76,98,95,109,116,177,11,50,118,175,139,56,143,203,150,72,38,136,66,133,28,111,117,119,198,179,134,128,143,203,72,136,31,119,151,198,38,92,139,146,180,28,193,173,158,73,179],
    "HBE": [165,155,17,10,55,26,29,41,104,87,127,184,24,168,153,1,141,98,170,186,137,179,167,33,205,7,42]
}

# Step 1 — sets for the three main categories
energy_set = set(data['ENERGY'])
thermal_set = set(data['THERMAL'])
iaq_set = set(data['IAQ'])

# Step 2 — remove overlaps (priority: ENERGY > THERMAL > IAQ)
thermal_set -= energy_set
iaq_set -= (energy_set | thermal_set)

# Step 3 — count unique citations in each category
energy_count = len(energy_set)
thermal_count = len(thermal_set)
iaq_count = len(iaq_set)

# Step 4 — total assigned so far
total_three_categories = energy_count + thermal_count + iaq_count

# Step 5 — get the full set of 207 unique citations
all_unique_citations = set(range(1, 208))  # 1 to 207

# Step 6 — remaining citations
remaining_citations_set = all_unique_citations - (energy_set | thermal_set | iaq_set)
remaining_citations_count = len(remaining_citations_set)

# Step 7 — final total check
total_unique_citations = total_three_categories + remaining_citations_count

print("Unique citations in ENERGY:", energy_count)
print("Unique citations in THERMAL:", thermal_count)
print("Unique citations in IAQ:", iaq_count)
print("Total citations in these three categories:", total_three_categories)
print("Remaining citations from other categories:", remaining_citations_count)
print("Total unique citations overall:", total_unique_citations)
# Out:
# Unique citations in ENERGY: 81
# Unique citations in THERMAL: 48
# Unique citations in IAQ: 17
# Total citations in these three categories: 146
# Remaining citations from other categories: 61
# Total unique citations overall: 207

# %%
# Original sets
energy_set = set(data['ENERGY'])
thermal_set = set(data['THERMAL'])
iaq_set = set(data['IAQ'])
sensing_set = set(data['SENSING'])

# Remove numbers that appear in ENERGY, THERMAL, or IAQ
clean_sensing_set = sensing_set - (energy_set | thermal_set | iaq_set)

# Convert to sorted list
clean_sensing_list = sorted(clean_sensing_set)

# Output
print("Cleaned SENSING list (unique numbers, not in ENERGY, THERMAL, IAQ):")
print(clean_sensing_list)
print("Count:", len(clean_sensing_list))
# Out:
# Cleaned SENSING list (unique numbers, not in ENERGY, THERMAL, IAQ):
# [11, 50, 53, 56, 76, 92, 95, 98, 111, 113, 116, 117, 118, 133, 150, 175, 177, 189, 201]
# Count: 19

# %%
data = {
    "INTRO": [8, 27, 9, 35],
    "METHD1": [74, 59, 192],
    "STANDARDS": [32,185,36,37,39,14,82,15,81,19,71,83,21,39,36,37,112,3,97,36],
    "ENERGY": [22,18,28,94,123,143,20,30,44,51,90,183,191,202,80,148,63,88,85,178,63,88,110,152,166,179,68,161,195,107,86,1,164,1,4,10,12,13,17,20,24,29,30,40,41,43,47,51,61,65,73,75,80,90,100,101,104,106,110,115,123,132,134,139,140,148,160,166,171,176,179,181,183,190,191,195,4,10,17,10,17,41,77,104,127,130,114,44,143,203,72,136,66,31,119,151,198,38,96,28,193,182,84,12,173,158,73,179,139,146,180],
    "THERMAL": [174,114,44,143,203,136,66,119,31,38,96,28,84,12,173,158,204,58,60,147,99,162,163,172,138,108,78,199,34,64,70,89,135,67,121,79,120,187,125,188,147,162,163,172,99,109,138,157,196,131,103,91,54,126,145,44,124,134,128,79,114,93,67,58,60,1,141,149,1,2,4,10,24,29,41,49,51,51,52,61,65,69,73,75,80,90,93,104,115,123,132,134,140,148,159,179,195,200,4,10,23,10,41,77,104,127,156,159,160,105,156,134,124,145,126,54,157,196,79,114,143,93,73,179],
    "IAQ": [144,6,16,48,46,129,44,122,46,195,5,195,57,24,72,207,46,195,129,62,206,44,169,45,129,61,195,183,102,1,141,1,4,10,13,44,51,61,65,73,90,93,102,115,129,142,152,183,195,202,4,10,23,10,77,127,156,130,156,197,128,44,72,136,38],
    "SENSING": [113,201,189,53,76,98,95,109,116,177,11,50,118,175,139,56,143,203,150,72,38,136,66,133,28,111,117,119,198,179,134,128,143,203,72,136,31,119,151,198,38,92,139,146,180,28,193,173,158,73,179],
    "HBE": [165,155,17,10,55,26,29,41,104,87,127,184,24,168,153,1,141,98,170,186,137,179,167,33,205,7,42]
}

# Step 1 — sets for the three main categories
energy_set = set(data['ENERGY'])
thermal_set = set(data['THERMAL'])
iaq_set = set(data['IAQ'])

# Step 2 — remove overlaps (priority: ENERGY > THERMAL > IAQ)
thermal_set -= energy_set
iaq_set -= (energy_set | thermal_set)

# Step 3 — combine all assigned so far
assigned_set = energy_set | thermal_set | iaq_set

# Step 4 — get the full set of 207 unique citations
all_citations = set(range(1, 208))  # 1 to 207

# Step 5 — remaining citations in other categories
other_set = all_citations - assigned_set

# Step 6 — counts
counts = {
    "ENERGY": len(energy_set),
    "THERMAL": len(thermal_set),
    "IAQ": len(iaq_set),
    "OTHER": len(other_set)
}

# Step 7 — final total check
total = sum(counts.values())

# Step 8 — print results
for cat, count in counts.items():
    print(f"{cat}: {count} citations")
print(f"Total unique citations overall: {total}")
# Out:
# ENERGY: 81 citations
# THERMAL: 48 citations
# IAQ: 17 citations
# OTHER: 61 citations
# Total unique citations overall: 207

# %%
sequence = """
o
t
t
t
t
i
e
o
e
t
t
t
e
t
t
e
t
t
e
i
o
o
t
o
o
o
e
e
t
t
o
o
o
t
t
o
e
o
o
i
t
t
i
t
t
t
e
o
t
t
o
t
t
t
e
e
e
e
i
t
t
e
t
o
o
o
"""

# Clean up and split into letters
letters = sequence.split()

# Count each letter
from collections import Counter
counts = Counter(letters)

# Print counts
for letter, count in counts.items():
    print(f"{letter}: {count}")

# Unique letters
print(f"Number of unique letters: {len(counts)}")
# Out:
# o: 18
# t: 29
# i: 5
# e: 14
# Number of unique letters: 4
